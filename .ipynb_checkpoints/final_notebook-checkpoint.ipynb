# %%
from surprise.model_selection import train_test_split, KFold

# %% [markdown]
# # 1. Importing & EDA (Pandas)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ratings_df = pd.read_csv('data/ratings.csv')
ratings_df.drop('timestamp', axis=1, inplace=True)

# %%
print('Number of Users = ', len(ratings_df['userId'].unique()))
print('Number of Movies = ', len(ratings_df['movieId'].unique()))
print(ratings_df.shape)
# Out:
# Number of Users =  610
# Number of Movies =  9724
# (100836, 3)

# %%
ratings_df.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
user_rating_count = ratings_df['userId'].value_counts()

fig, ax = plt.subplots(figsize=(5,10))
plt.boxplot(user_rating_count);

# %%
user_rating_count
# Out:
# 414    2698
# 599    2478
# 474    2108
# 448    1864
# 274    1346
#        ...
# 406      20
# 595      20
# 569      20
# 431      20
# 442      20
# Name: userId, Length: 610, dtype: int64

# %% [markdown]
# # 2. Exploring Model-Based Methods

# %% [markdown]
# 1. I am choosing a model-based method over memory-based methods due to the size (100,000 entries) of the dataset
# 2. I will start by building a Collaborative Filtering recommender system
#     - Predictor algorithm will be chosen upon the lowest RMSE score

# %%
import numpy as np
from surprise import Reader, Dataset
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise.model_selection import KFold
from surprise.prediction_algorithms import BaselineOnly, SVD, SVDpp, NMF, SlopeOne, CoClustering

# %%
reader = Reader()
data = Dataset.load_from_df(ratings_df, reader)

# %%
def predictor_RMSE(pred, data, cv=None, njobs=0):
    """
    if 'cv' parameter not specified, cv = 5
    
    """
    pred_base = pred()
    cv_pred = cross_validate(pred_base, data, cv=cv, n_jobs=njobs)
    
    print(np.mean(cv_pred['test_rmse']))

# %%
predictor_RMSE(BaselineOnly, data, njobs=-1)

# %%
predictor_RMSE(SVD, data, njobs=-1)

# %%
# predictor_RMSE(SVDpp, data, njobs=-1)

# %%
predictor_RMSE(NMF, data, njobs=-1)

# %%
predictor_RMSE(SlopeOne, data, njobs=-1)

# %%
predictor_RMSE(CoClustering, data, njobs=-1)

# %% [markdown]
# **OBSERVATION**
# 1. BaselineOnly and SVD continuously get very close results, with the lower of the two alternating constantly
# 2. BaselineOnly (along with all other baselines included in Surprise) use ALS as the default
#     - this could explain the baseline's comparable results to SVD

# %% [markdown]
# ### Optimizing SVD

# %%
param_grid = {'n_factors':[50, 100, 150],
              'n_epochs': [10, 20, 30]}

svd_grid = GridSearchCV(SVD, param_grid=param_grid, n_jobs=-1)
svd_grid.fit(data)

# %%
print(svd_grid.best_score)
print(svd_grid.best_params)

# %%
param_grid = {'n_factors':[10, 25, 50],
              'lr_all': [0.002, 0.005],
              'reg_all': [0.02, 0.1, 0.2]}

svd_grid = GridSearchCV(SVD, param_grid=param_grid, n_jobs=-1)
svd_grid.fit(data)

# %%
print(svd_grid.best_score)
print(svd_grid.best_params)

# %% [markdown]
# # 3. Making Predictions

# %%
dataset = data.build_full_trainset()

# %%
dataset = data.build_full_trainset()

svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(dataset)

# %%
svd.predict(5, 10)
# Out:
# Prediction(uid=5, iid=10, r_ui=None, est=3.4621454779928045, details={'was_impossible': False})

# %% [markdown]
# # 3. Recommendations For Preexisting Users

# %% [markdown]
# # 4. Addressing 'Cold-Start' Problem

# %%
#importing movie titles
title_df = pd.read_csv('data/movies.csv')

#merging ratings and titles
title_rating_df = pd.merge(ratings_df, title_df, on='movieId')

#creating groupby by title and genres
rating_count_df = title_rating_df.groupby(by=['title', 'genres', 'movieId'])

#aggregating the number of ratings for each title 
rating_count_df= rating_count_df['rating'].count().reset_index().rename(columns = {'rating': 'rating_count'})

#display in descending order based on rating_count
rating_count_df = rating_count_df.sort_values(by='rating_count', ascending=False)

#SOURCE FOR CODE
#https://www.youtube.com/watch?v=kccT0FVK6OY&list=PL-IOEPSNs4rYKHhicQ210AXk5yuzrkeH1&index=12&ab_channel=KrishNaik

# %%
rating_count_df.head()
# Out:
#                                  title                       genres  movieId  \
# 3161               Forrest Gump (1994)     Comedy|Drama|Romance|War      356
# 7597  Shawshank Redemption, The (1994)                  Crime|Drama      318
# 6868               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller      296
# 7684  Silence of the Lambs, The (1991)        Crime|Horror|Thriller      593
# 5515                Matrix, The (1999)       Action|Sci-Fi|Thriller     2571
#
#       rating_count
# 3161           329
# 7597           317
# 6868           307
# 7684           279
# 5515           278

# %%
import re

# %%
def movie_rater():
    #creating new userId to be appended to the end of ratings_df
    userId = ratings_df['userId'].max() + 1
    rating_list = []
    
    #collecting genre preferences
    #DISPLAY A LIST OF ALL GENRES AVAILABLE? 
    top_genres = []
    top_genres.append(input('What is your favorite movie genre?'))
    top_genres.append(input('What is your SECOND favorite movie genre?'))
    least_fav_genre = input('What is your LEAST favorite movie genre?')
    
    print('----------------------------------------------')
    print('You will now be shown 5 {} and {} movies, please rate them from 0.5 - 5'.format(top_genres[0], top_genres[1]))
    print('If you have not seen the given movie, please enter n')
    
    #Prompting the user to rate 5 MOST VIEWED movies of their preferred genres
    num = 5
    index = 0
    while num > 0:
        movie_df = rating_count_df[(rating_count_df['genres'].str.contains(top_genres[0])) 
                                & (rating_count_df['genres'].str.contains(top_genres[1]))]
        movie_df[(~movie_df['genres'].str.contains(least_fav_genre))]
        print('----------------------------------------------')
        
        movie = movie_df.iloc[index]
        print(movie)
        #ADD ERROR FOR INVALID INPUTS?
        rating = float(input('How do you rate this movie? Press n if you have not seen it'))
        if rating == 'n':
            index += 1
            continue 
        else: 
            # rated_movie is what gets appended to the ratings_df (what model is run on)
            rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
            rating_list.append(rated_movie)
            num -= 1
            index += 1
            
    #adding new user ratings (rating_list) to original ratings dataframe (ratings_df)
    ratings_df.append(rating_list, ignore_index=True)
    
    new_data = Dataset.load_from_df(ratings_df, reader)
    
    #training new model on updated_ratings_df
    svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
    svd.fit(new_data.build_full_trainset())

    
    #running model to predict new movies for user 
    
    movie_recs = []
    for m_id in ratings_df['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))

    
    print('----------------------------------------------')
    
    #displaying 5 recommendations
    print('We made 5 recommendations for you!')
    
    ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)

    n = 5
    rec_list = []
    for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break
    
    print('----------------------------------------------')
    
    #Continue rating or stop
    print('The more movies you rate, the better recommendations we can make!')
    
    second_round_rating = input('Would you like to coninue rating? [y/n]')
    if second_round_rating == 'n':
        print('Thank you for participating in Jack\'s Phase 4 Project =D')
    

    rec_list
    #ranked_movies_df = pd.DataFrame(ranked_movies[:5])
    
    
    
#     rating_list = []
#     num = 5
#     index = 0
#     while num > 0:
#         movie = ranked_movies[index]
#         print(movie)
#         rating = float(input('How do you rate this movie? Press n if you have not seen it'))
#         if rating == 'n':
#             index += 1
#             continue 
#         else: 
#             rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
#             rating_list.append(rated_movie)
#             num -= 1
#             index += 1

# %%
rating_count_df
# Out:
#                                           title                       genres  \
# 3161                        Forrest Gump (1994)     Comedy|Drama|Romance|War
# 7597           Shawshank Redemption, The (1994)                  Crime|Drama
# 6868                        Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 7684           Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 5515                         Matrix, The (1999)       Action|Sci-Fi|Thriller
# ...                                         ...                          ...
# 4774                          King Ralph (1991)                       Comedy
# 4772                     King Kong Lives (1986)             Adventure|Sci-Fi
# 4767                        Kindred, The (1986)                Horror|Sci-Fi
# 4766                  Kindergarten Cop 2 (2016)                Action|Comedy
# 9723  À nous la liberté (Freedom for Us) (1931)               Comedy|Musical
#
#       movieId  rating_count
# 3161      356           329
# 7597      318           317
# 6868      296           307
# 7684      593           279
# 5515     2571           278
# ...       ...           ...
# 4774     7005             1
# 4772     2368             1
# 4767     2740             1
# 4766   158254             1
# 9723     5560             1
#
# [9724 rows x 4 columns]

# %%
userId = ratings_df['userId'].max() + 1
rating_list = []
    
    #collecting genre preferences
    #DISPLAY A LIST OF ALL GENRES AVAILABLE? 
top_genres = []
top_genres.append(input('What is your favorite movie genre?'))
top_genres.append(input('What is your SECOND favorite movie genre?'))
least_fav_genre = input('What is your LEAST favorite movie genre?')
    
print('----------------------------------------------')
print('You will now be shown 5 {} and {} movies, please rate them from 0.5 - 5'.format(top_genres[0], top_genres[1]))
print('If you have not seen the given movie, please enter n')
    
    #Prompting the user to rate 5 MOST VIEWED movies of their preferred genres
num = 5
index = 0
while num > 0:
        movie_df = rating_count_df[(rating_count_df['genres'].str.contains(top_genres[0])) 
                                & (rating_count_df['genres'].str.contains(top_genres[1]))]
        movie_df[(~movie_df['genres'].str.contains(least_fav_genre))]
        print('----------------------------------------------')
        
        movie = movie_df.iloc[index]
        print(movie)
        #ADD ERROR FOR INVALID INPUTS?
        rating = float(input('How do you rate this movie? Press n if you have not seen it'))
        if rating == 'n':
            index += 1
            continue 
        else: 
            # rated_movie is what gets appended to the ratings_df (what model is run on)
            rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
            rating_list.append(rated_movie)
            num -= 1
            index += 1
            
    #adding new user ratings (rating_list) to original ratings dataframe (ratings_df)
ratings_df.append(rating_list, ignore_index=True)
    
new_data = Dataset.load_from_df(ratings_df, reader)
    
    #training new model on updated_ratings_df
svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(new_data.build_full_trainset())

    
    #running model to predict new movies for user 
    
movie_recs = []
for m_id in ratings_df['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))

    
print('----------------------------------------------')
    
    #displaying 5 recommendations
print('We made 5 recommendations for you!')
    
ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)

n = 5
rec_list = []
for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break
# Out:
# What is your favorite movie genre?Action
# What is your SECOND favorite movie genre?Comedy
# What is your LEAST favorite movie genre?Thriller
# ----------------------------------------------
# You will now be shown 5 Action and Comedy movies, please rate them from 0.5 - 5
# If you have not seen the given movie, please enter n
# ----------------------------------------------
# title                                   True Lies (1994)
# genres          Action|Adventure|Comedy|Romance|Thriller
# movieId                                              380
# rating_count                                         178
# Name: 8953, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# title           Men in Black (a.k.a. MIB) (1997)
# genres                      Action|Comedy|Sci-Fi
# movieId                                     1580
# rating_count                                 165
# Name: 5585, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# title                      Mask, The (1994)
# genres          Action|Comedy|Crime|Fantasy
# movieId                                 367
# rating_count                            157
# Name: 5491, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# title           Pirates of the Caribbean: The Curse of the Bla...
# genres                            Action|Adventure|Comedy|Fantasy
# movieId                                                      6539
# rating_count                                                  149
# Name: 6649, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# title                        Princess Bride, The (1987)
# genres          Action|Adventure|Comedy|Fantasy|Romance
# movieId                                            1197
# rating_count                                        142
# Name: 6811, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# We made 5 recommendations for you!
# Recommendation #  1 :  906    Lawrence of Arabia (1962)
# Name: title, dtype: object
#
# Recommendation #  2 :  602    Dr. Strangelove or: How I Learned to Stop Worr...
# Name: title, dtype: object
#
# Recommendation #  3 :  277    Shawshank Redemption, The (1994)
#  (68952, 3.393263559477081),
#  (46850, 3.3930907112946858),
#  (61024, 3.3929516851677346),
#  (1753, 3.3924634241302383),
#  (104069, 3.3922472141172473),
#  (3074, 3.392163971321194),
#  (4225, 3.3919277752215895),
#  (6001, 3.391901921069873),
#  (7139, 3.391566766541474),
#  (2889, 3.391524391943998),
#  (1729, 3.39142596608271),
#  (85881, 3.391359512482356),
#  (2132, 3.3906016802574763),
#  (3111, 3.390504899684997),
#  (156371, 3.390359525637905),
#  (7767, 3.3902860714880387),
#  (4019, 3.3902712230538947),
#  (2000, 3.390219286011005),
#  (122904, 3.389606577650331),
#  (8937, 3.389270650282333),
#  (4914, 3.3889943055739433),
#  (1232, 3.3889063440014033),
#  (506, 3.3886985534942804),
#  (4754, 3.3886829949682107),
#  (97913, 3.3884267686371885),
#  (2135, 3.388064891779892),
#  (3181, 3.3873554717537457),
#  (4017, 3.3873240283203914),
#  (104283, 3.3871521475834956),
#  (2594, 3.3870036209521923),
#  (2730, 3.386689687724571),
#  (69, 3.386441559148807),
#  (474, 3.3861374930335),
#  (7569, 3.3859782665141833),
#  (8581, 3.3859722351582286),
#  (70599, 3.385438249405188),
#  (117590, 3.3853708256084643),
#  (2131, 3.385303859090109),
#  (5577, 3.385282379383649),
#  (96488, 3.384905139758652),
#  (105844, 3.3847465808336836),
#  (116823, 3.3845291134182003),
#  (1354, 3.384438595779171),
#  (55908, 3.3839897648711377),
#  (98243, 3.3838889725279886),
#  (8528, 3.3836665565173147),
#  (1366, 3.383629507970963),
#  (6305, 3.383491167397994),
#  (79008, 3.3831152719151123),
#  (3685, 3.3829668358600515),
#  (91542, 3.3827865786403186),
#  (4117, 3.382703489920948),
#  (117881, 3.3825804748881962),
#  (2511, 3.382222874651046),
#  (136449, 3.3821577995494785),
#  (6708, 3.3819487208011694),
#  (3360, 3.381632630467094),
#  (57274, 3.3813194498692605),
#  (431, 3.3811598694301157),
#  (4016, 3.38099257697457),
#  (27815, 3.380765896731761),
#  (4738, 3.3802714418434525),
#  (1836, 3.3801496640910766),
#  (1097, 3.3800782148392643),
#  (81562, 3.3799176518971614),
#  (3676, 3.379549751195909),
#  (1361, 3.3793172423877618),
#  (3526, 3.3792738411476866),
#  ...]

# %%
class User:
     def __init__(self, rec1):
        self.rec1 = rec1
#         self.rec2 = rec2
#         self.rec3 = rec3
#         self.rec4 = rec4
#         self.rec5 = rec5

# %%
userId = ratings_df['userId'].max() + 1
rating_list = []
    
    #collecting genre preferences
    #DISPLAY A LIST OF ALL GENRES AVAILABLE? 
top_genres = []
top_genres.append(input('What is your favorite movie genre?'))
top_genres.append(input('What is your SECOND favorite movie genre?'))
least_fav_genre = input('What is your LEAST favorite movie genre?')
    
print('----------------------------------------------')
print('You will now be shown 5 {} and {} movies, please rate them from 0.5 - 5'.format(top_genres[0], top_genres[1]))
print('If you have not seen the given movie, please enter n')
    
    #Prompting the user to rate 5 MOST VIEWED movies of their preferred genres
num = 5
index = 0
while num > 0:
        movie_df = rating_count_df[(rating_count_df['genres'].str.contains(top_genres[0])) 
                                & (rating_count_df['genres'].str.contains(top_genres[1]))]
        movie_df[(~movie_df['genres'].str.contains(least_fav_genre))]
        print('----------------------------------------------')
        
        movie = movie_df.iloc[index]
        print(movie)
        #ADD ERROR FOR INVALID INPUTS?
        rating = float(input('How do you rate this movie? Press n if you have not seen it'))
        if rating == 'n':
            index += 1
            continue 
        else: 
            # rated_movie is what gets appended to the ratings_df (what model is run on)
            rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
            rating_list.append(rated_movie)
            num -= 1
            index += 1
            
    #adding new user ratings (rating_list) to original ratings dataframe (ratings_df)
ratings_df.append(rating_list, ignore_index=True)
    
new_data = Dataset.load_from_df(ratings_df, reader)
    
    #training new model on updated_ratings_df
svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(new_data.build_full_trainset())

    
    #running model to predict new movies for user 
    
movie_recs = []
for m_id in ratings_df['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))
    
print('----------------------------------------------')
    
print('We made 5 recommendations for you!')
    
ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)


#displaying 5 recommendations
n = 5
rec_list = []
for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break
            

#ratings_df_pruned 

# ROUND 2 RATINGS --------------------------------------------------------------------            

            
#creating a list of recommended movies
# each entry is a dictionary consisting of the movieId and the title
#top 50 recommended movies are added to ensure the user can rate 5 before recommendations run out 
lib_list = []
for i in range(50):
    rec_dict = {'movieId': ranked_movies[i][0], 'title': title_df[title_df['movieId'] == ranked_movies[i][0]]}
    rec_dict_copy = rec_dict.copy()
    lib_list.append(rec_dict_copy)


rating_list = []
num = 5
index = 0
while num > 0:
    movie = lib_list[index]['title']
    print(movie)
    #ADD ERROR FOR INVALID INPUTS?
    rating = float(input('How do you rate this movie? Press n if you have not seen it'))
    if rating == 'n':
        index += 1
        continue 
    else: 
        # rated_movie is what gets appended to the ratings_df (what model is run on)
        rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
        rating_list.append(rated_movie)
        num -= 1
        index += 1    


        
ratings_df.append(rating_list, ignore_index=True)
    
new_data = Dataset.load_from_df(ratings_df, reader)
    
#training new model on updated_ratings_df
svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(new_data.build_full_trainset())

    
#running model to predict new movies for user 
    
movie_recs = []
for m_id in ratings_df_pruned['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))
    
print('----------------------------------------------')
    
print('We made 5 recommendations for you!')
    
ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)


#displaying 5 recommendations
n = 5
rec_list = []
for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break
    

# user = User([{'movieId': ranked_movies[0][0], 'title': title_df[title_df['movieId'] == ranked_movies[0][0]]},
#             {'movieId': ranked_movies[1][0], 'title': title_df[title_df['movieId'] == ranked_movies[1][0]]},
#             {'movieId': ranked_movies[2][0], 'title': title_df[title_df['movieId'] == ranked_movies[2][0]]},
#             {'movieId': ranked_movies[3][0], 'title': title_df[title_df['movieId'] == ranked_movies[3][0]]},
#             {'movieId': ranked_movies[4][0], 'title': title_df[title_df['movieId'] == ranked_movies[4][0]]}])
# Out:
# What is your favorite movie genre?Action
# What is your SECOND favorite movie genre?Romance
# What is your LEAST favorite movie genre?Drama
# ----------------------------------------------
# You will now be shown 5 Action and Romance movies, please rate them from 0.5 - 5
# If you have not seen the given movie, please enter n
# ----------------------------------------------
# title                                   True Lies (1994)
# genres          Action|Adventure|Comedy|Romance|Thriller
# movieId                                              380
# rating_count                                         178
# Name: 8953, dtype: object
# How do you rate this movie? Press n if you have not seen it5
# ----------------------------------------------
# title                      Speed (1994)
# genres          Action|Romance|Thriller
# movieId                             377
# rating_count                        171
# Name: 7916, dtype: object
# How do you rate this movie? Press n if you have not seen it1
# ----------------------------------------------
# title                        Princess Bride, The (1987)
# genres          Action|Adventure|Comedy|Fantasy|Romance
# movieId                                            1197
# rating_count                                        142
# Name: 6811, dtype: object
# How do you rate this movie? Press n if you have not seen it2
# ----------------------------------------------
# title                              Twister (1996)
# genres          Action|Adventure|Romance|Thriller
# movieId                                       736
# rating_count                                  123
# Name: 9004, dtype: object
# How do you rate this movie? Press n if you have not seen it5
# ----------------------------------------------
# title           Crouching Tiger, Hidden Dragon (Wo hu cang lon...
# genres                                       Action|Drama|Romance
# movieId                                                      3996
# rating_count                                                  110
# Name: 2060, dtype: object
# How do you rate this movie? Press n if you have not seen it3
# ----------------------------------------------
# We made 5 recommendations for you!
# Recommendation #  1 :  909    Apocalypse Now (1979)
# Name: title, dtype: object
#
# Recommendation #  2 :  2226    Fight Club (1999)
# Name: title, dtype: object
#
# Recommendation #  3 :  277    Shawshank Redemption, The (1994)
# Name: title, dtype: object
#
# Recommendation #  4 :  461    Schindler's List (1993)
# Name: title, dtype: object
#
# Recommendation #  5 :  585    Wallace & Gromit: The Best of Aardman Animatio...
# Name: title, dtype: object
#
#      movieId                  title            genres
# 909     1208  Apocalypse Now (1979)  Action|Drama|War
# How do you rate this movie? Press n if you have not seen it5
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller
# How do you rate this movie? Press n if you have not seen it2
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama
# How do you rate this movie? Press n if you have not seen it1
#      movieId                    title     genres
# 461      527  Schindler's List (1993)  Drama|War
# How do you rate this movie? Press n if you have not seen it4
#      movieId                                              title  \
# 585      720  Wallace & Gromit: The Best of Aardman Animatio...
#
#                          genres
# 585  Adventure|Animation|Comedy
# How do you rate this movie? Press n if you have not seen it0.5
# ----------------------------------------------
# We made 5 recommendations for you!
# Recommendation #  1 :  602    Dr. Strangelove or: How I Learned to Stop Worr...
# Name: title, dtype: object
#
# Recommendation #  2 :  277    Shawshank Redemption, The (1994)
# Name: title, dtype: object
#
# Recommendation #  3 :  906    Lawrence of Arabia (1962)
# Name: title, dtype: object
#
# Recommendation #  4 :  224    Star Wars: Episode IV - A New Hope (1977)
# Name: title, dtype: object
#
# Recommendation #  5 :  3638    Lord of the Rings: The Fellowship of the Ring,...
# Name: title, dtype: object

# %%
title_df[title_df['movieId'] == ranked_movies[0][0]]
# Out:
#      movieId                                              title      genres
# 602      750  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War

# %%
ranked_movies[1][0]
# Out:
# 318

# %%
lib_list[0]
# Out:
# {'movieId': 318,
#  'title':      movieId                             title       genres
#  277      318  Shawshank Redemption, The (1994)  Crime|Drama}

# %%
lib_list[0]['title']
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %%
ratings_df
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
ratings_df_pruned = ratings_df

# %%
ratings_df_pruned
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
rating_list[0]['userId']
# Out:
# 611

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == 611]
# Out:
#        userId  movieId  rating
# 2401       19      611     2.0
# 20723     136      611     1.0
# 59314     387      611     1.5
# 85377     555      611     2.0
# 96252     603      611     3.0
# 97136     604      611     5.0

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[0]['userId']]
# Out:
#        userId  movieId  rating
# 2401       19      611     2.0
# 20723     136      611     1.0
# 59314     387      611     1.5
# 85377     555      611     2.0
# 96252     603      611     3.0
# 97136     604      611     5.0

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[0]['userId']]
# Out:
#        userId  movieId  rating
# 2401       19      611     2.0
# 20723     136      611     1.0
# 59314     387      611     1.5
# 85377     555      611     2.0
# 96252     603      611     3.0
# 97136     604      611     5.0

# %%
ratings_df_pruned['movieId'].drop_duplicates(keep='first', inplace=True)

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[0]['userId']]
# Out:
#        userId  movieId  rating
# 2401       19      611     2.0
# 20723     136      611     1.0
# 59314     387      611     1.5
# 85377     555      611     2.0
# 96252     603      611     3.0
# 97136     604      611     5.0

# %%
rec_index = []
for i in range(len(rating_list)):
    rec_index.append(ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[i]['movieId']].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-870604230fdc> in <module>
#       1 rec_index = []
#       2 for i in range(len(rating_list)):
# ----> 3     rec_index.append(ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[i]['movieId']].index)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     363
#     364         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 365             raise ValueError("Can only compare identically-labeled Series objects")
#     366
#     367         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == 909]
# Out:
#        userId  movieId  rating
# 7130       50      909     3.0
# 13232      84      909     3.0
# 13564      89      909     2.5
# 16246     105      909     4.0
# 17218     110      909     4.0
# 18001     113      909     4.0
# 24992     177      909     5.0
# 30743     216      909     4.0
# 31038     217      909     4.0
# 40632     275      909     5.0
# 43247     290      909     5.0
# 46876     307      909     4.0
# 48712     315      909     5.0
# 56675     377      909     4.0
# 62150     412      909     3.0
# 62633     414      909     4.0
# 65015     415      909     4.5
# 65598     421      909     4.0
# 72525     469      909     5.0
# 73292     474      909     4.0
# 77328     483      909     5.0
# 81586     517      909     0.5
# 90614     590      909     4.0
# 92244     597      909     4.0
# 96289     603      909     4.0
# 97497     606      909     4.0
# 99589     610      909     4.5

# %%
int(rating_list[0]['movieId'])
# Out:
# 1208

# %%
rating_list
# Out:
# [{'userId': 611,
#   'movieId': 909    1208
#   Name: movieId, dtype: int64,
#   'rating': 5.0},
#  {'userId': 611,
#   'movieId': 2226    2959
#   Name: movieId, dtype: int64,
#   'rating': 2.0},
#  {'userId': 611,
#   'movieId': 277    318
#   Name: movieId, dtype: int64,
#   'rating': 1.0},
#  {'userId': 611,
#   'movieId': 461    527
#   Name: movieId, dtype: int64,
#   'rating': 4.0},
#  {'userId': 611,
#   'movieId': 585    720
#   Name: movieId, dtype: int64,
#   'rating': 0.5}]

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[0]['userId']].index
# Out:
# Int64Index([2401, 20723, 59314, 85377, 96252, 97136], dtype='int64')

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[1]['userId']].index
# Out:
# Int64Index([2401, 20723, 59314, 85377, 96252, 97136], dtype='int64')

# %%
ratings_df_pruned[ratings_df_pruned['movieId'] == rating_list[0]['userId']].index
# Out:
# Int64Index([2401, 20723, 59314, 85377, 96252, 97136], dtype='int64')

# %%
rating_list[0]
# Out:
# {'userId': 611,
#  'movieId': 909    1208
#  Name: movieId, dtype: int64,
#  'rating': 5.0}

# %%
rating_list[1]
# Out:
# {'userId': 611,
#  'movieId': 2226    2959
#  Name: movieId, dtype: int64,
#  'rating': 2.0}

# %%
userId = ratings_df['userId'].max() + 1
rating_list = []
    
    #collecting genre preferences
    #DISPLAY A LIST OF ALL GENRES AVAILABLE? 
top_genres = []
top_genres.append(input('What is your favorite movie genre?'))
top_genres.append(input('What is your SECOND favorite movie genre?'))
least_fav_genre = input('What is your LEAST favorite movie genre?')
    
print('----------------------------------------------')
print('You will now be shown 5 {} and {} movies, please rate them from 0.5 - 5'.format(top_genres[0], top_genres[1]))
print('If you have not seen the given movie, please enter n')
    
    #Prompting the user to rate 5 MOST VIEWED movies of their preferred genres
num = 5
index = 0
while num > 0:
        movie_df = rating_count_df[(rating_count_df['genres'].str.contains(top_genres[0])) 
                                & (rating_count_df['genres'].str.contains(top_genres[1]))]
        movie_df[(~movie_df['genres'].str.contains(least_fav_genre))]
        print('----------------------------------------------')
        
        movie = movie_df.iloc[index]
        print(movie)
        #ADD ERROR FOR INVALID INPUTS?
        rating = float(input('How do you rate this movie? Press n if you have not seen it'))
        if rating == 'n':
            index += 1
            continue 
        else: 
            # rated_movie is what gets appended to the ratings_df (what model is run on)
            rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
            rating_list.append(rated_movie)
            num -= 1
            index += 1
            
    #adding new user ratings (rating_list) to original ratings dataframe (ratings_df)
ratings_df.append(rating_list, ignore_index=True)
    
new_data = Dataset.load_from_df(ratings_df, reader)
    
    #training new model on updated_ratings_df
svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(new_data.build_full_trainset())

    
    #running model to predict new movies for user 
    
movie_recs = []
for m_id in ratings_df['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))
    
print('----------------------------------------------')
    
print('We made 5 recommendations for you!')
    
ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)


#displaying 5 recommendations
n = 5
rec_list = []
for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break
            

#ratings_df_pruned 

# ROUND 2 RATINGS --------------------------------------------------------------------            

            
#creating a list of recommended movies
# each entry is a dictionary consisting of the movieId and the title
#top 50 recommended movies are added to ensure the user can rate 5 before recommendations run out 
lib_list = []
for i in range(50):
    rec_dict = {'movieId': ranked_movies[i][0], 'title': title_df[title_df['movieId'] == ranked_movies[i][0]]}
    rec_dict_copy = rec_dict.copy()
    lib_list.append(rec_dict_copy)


rating_list = []
num = 5
index = 0
while num > 0:
    movie = lib_list[index]['title']
    print(movie)
    #ADD ERROR FOR INVALID INPUTS?
    rating = float(input('How do you rate this movie? Press n if you have not seen it'))
    if rating == 'n':
        index += 1
        continue 
    else: 
        # rated_movie is what gets appended to the ratings_df (what model is run on)
        rated_movie = {'userId':userId, 'movieId':movie['movieId'], 'rating':rating}
        rating_list.append(rated_movie)
        num -= 1
        index += 1    


        
ratings_df.append(rating_list, ignore_index=True)
    
new_data = Dataset.load_from_df(ratings_df, reader)
    
#training new model on updated_ratings_df
svd = SVD(n_factors=10, lr_all = 0.005, reg_all=0.02)
svd.fit(new_data.build_full_trainset())

    
#running model to predict new movies for user 
    
movie_recs = []
for m_id in ratings_df_pruned['movieId'].unique():
        movie_recs.append( (m_id,svd.predict(500,m_id)[3]))
    
print('----------------------------------------------')
    
print('We made 5 recommendations for you!')
    
ranked_movies = sorted(movie_recs, key=lambda x:x[1], reverse=True)


#displaying 5 recommendations
n = 5
rec_list = []
for idx, rec in enumerate(ranked_movies):
        title = title_df.loc[title_df['movieId'] == int(rec[0])]['title']
        rec_list.append(title)
        print('Recommendation # ', idx+1, ': ', title, '\n')
        n -= 1
        if n == 0:
            break

# %%
rating_list
# Out:
# [{'userId': 611,
#   'movieId': 909    1208
#   Name: movieId, dtype: int64,
#   'rating': 5.0},
#  {'userId': 611,
#   'movieId': 2226    2959
#   Name: movieId, dtype: int64,
#   'rating': 2.0},
#  {'userId': 611,
#   'movieId': 277    318
#   Name: movieId, dtype: int64,
#   'rating': 1.0},
#  {'userId': 611,
#   'movieId': 461    527
#   Name: movieId, dtype: int64,
#   'rating': 4.0},
#  {'userId': 611,
#   'movieId': 585    720
#   Name: movieId, dtype: int64,
#   'rating': 0.5}]

# %%
rating_count_df[rating_count_df['movieId'] == 1208]
# Out:
#                      title            genres  movieId  rating_count
# 563  Apocalypse Now (1979)  Action|Drama|War     1208           107

# %%
ranked_movies
# Out:
# [(750, 4.238238800647567),
#  (318, 4.194867794949821),
#  (1204, 4.096185101441784),
#  (260, 4.073934527355623),
#  (4993, 4.06084360728822),
#  (898, 4.054703252638522),
#  (1196, 4.050968048239799),
#  (2571, 4.043348235527336),
#  (1148, 4.016884132041051),
#  (858, 4.014131322383617),
#  (1136, 4.013845142301137),
#  (1197, 4.0054729050183235),
#  (1221, 4.004286109344903),
#  (48516, 4.003994795959802),
#  (2959, 3.9987749572343594),
#  (1201, 3.998580255209051),
#  (904, 3.9908854124087902),
#  (50, 3.984353715398212),
#  (56782, 3.975593649544636),
#  (1104, 3.972516006315612),
#  (1248, 3.9649388714529996),
#  (7361, 3.958156203498367),
#  (8874, 3.9526112358531122),
#  (1258, 3.9525253901580526),
#  (5952, 3.947412608329194),
#  (527, 3.9444753142329283),
#  (912, 3.943918366669447),
#  (923, 3.942216342325379),
#  (3275, 3.938594324788932),
#  (1206, 3.938273768347041),
#  (1210, 3.9372986067727824),
#  (5618, 3.936700212974716),
#  (2324, 3.9339336981063315),
#  (51255, 3.9297706887572095),
#  (4973, 3.928648534891648),
#  (4878, 3.928611721644151),
#  (3451, 3.9261664795571845),
#  (741, 3.9230444910795197),
#  (593, 3.9160449274228153),
#  (1089, 3.9103147443469757),
#  (1198, 3.9085988200325836),
#  (58559, 3.9076282477831783),
#  (1233, 3.9075411914558145),
#  (7153, 3.9043426679243636),
#  (2329, 3.902295890615668),
#  (1193, 3.8967448468588364),
#  (4011, 3.8962926435334593),
#  (1235, 3.8917443112376207),
#  (720, 3.8879665765311877),
#  (1228, 3.883489513202456),
#  (4226, 3.880178476225082),
#  (162, 3.880032254799317),
#  (5995, 3.866836685056185),
#  (1283, 3.8666877701932743),
#  (246, 3.866034839188277),
#  (933, 3.8631043974616257),
#  (951, 3.8607470257928393),
#  (1213, 3.8602547065986963),
#  (1199, 3.858729405598102),
#  (296, 3.8586798079338727),
#  (3030, 3.856682983045761),
#  (1230, 3.8564788731912945),
#  (1262, 3.8554839084102475),
#  (57669, 3.8551679227975924),
